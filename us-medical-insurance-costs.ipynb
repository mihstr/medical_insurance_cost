# %% [markdown]
# # U.S. Medical Insurance Costs

# %%
import pandas as pd
import matplotlib.pyplot as plt
# ---------------------------------

import duckdb
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# %sql duckdb:///:memory:
# # %sql duckdb:///path/to/file.db

# import pandas_ml as pdml
import sklearn.datasets as datasets
import geopandas

from jupyter_datatables import init_datatables_mode
# init_datatables_mode()

from summarytools import dfSummary, tabset
import sidetable
import sketch

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
raw_data = pd.DataFrame(pd.read_csv("insurance.csv"))

# %%
raw_data.describe(include="all")
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    13270.422265
# std     12110.011237
# min      1121.873900
# 25%      4740.287150
# 50%      9382.033000
# 75%     16639.912515
# max     63770.428010

# %%
dfSummary(raw_data, is_collapsible = True)
# tabset({
#     'titanic': dfSummary(titanic).render(),
#     'vaccine': dfSummary(vaccine).render()
#     })
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-1976" onclick = "coll_toggle_1976()">Show Summary - raw_data</button>
#     <div class="st-content" id="cont-1976">
#       <style type="text/css">
# #T_bd24e thead>tr>th {
#   text-align: left;
# }
# #T_bd24e_row0_col0, #T_bd24e_row1_col0, #T_bd24e_row2_col0, #T_bd24e_row3_col0, #T_bd24e_row4_col0, #T_bd24e_row5_col0, #T_bd24e_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_bd24e_row0_col1, #T_bd24e_row1_col1, #T_bd24e_row2_col1, #T_bd24e_row3_col1, #T_bd24e_row4_col1, #T_bd24e_row5_col1, #T_bd24e_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_bd24e_row0_col2, #T_bd24e_row1_col2, #T_bd24e_row2_col2, #T_bd24e_row3_col2, #T_bd24e_row4_col2, #T_bd24e_row5_col2, #T_bd24e_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_bd24e_row0_col3, #T_bd24e_row1_col3, #T_bd24e_row2_col3, #T_bd24e_row3_col3, #T_bd24e_row4_col3, #T_bd24e_row5_col3, #T_bd24e_row6_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_bd24e_row0_col4, #T_bd24e_row1_col4, #T_bd24e_row2_col4, #T_bd24e_row3_col4, #T_bd24e_row4_col4, #T_bd24e_row5_col4, #T_bd24e_row6_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_bd24e_row0_col5, #T_bd24e_row1_col5, #T_bd24e_row2_col5, #T_bd24e_row3_col5, #T_bd24e_row4_col5, #T_bd24e_row5_col5, #T_bd24e_row6_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_bd24e">
#   <caption><strong>Data Frame Summary</strong><br>raw_data<br>Dimensions: 1,338 x 7<br>Duplicates: 1</caption>
#   <thead>
#     <tr>
#       <th id="T_bd24e_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_bd24e_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_bd24e_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_bd24e_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_bd24e_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_bd24e_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd24e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bd24e_row0_col1" class="data row0 col1" ><strong>age</strong><br>[int64]</td>
#       <td id="T_bd24e_row0_col2" class="data row0 col2" >Mean (sd) : 39.2 (14.0)<br>min < med < max:<br>18.0 < 39.0 < 64.0<br>IQR (CV) : 24.0 (2.8)</td>
#       <td id="T_bd24e_row0_col3" class="data row0 col3" >47 distinct values</td>
#       <td id="T_bd24e_row0_col4" class="data row0 col4" ><img src = "tmp/raw_data_000.png"></img></td>
#       <td id="T_bd24e_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bd24e_row1_col1" class="data row1 col1" ><strong>sex</strong><br>[object]</td>
#       <td id="T_bd24e_row1_col2" class="data row1 col2" >1. male<br>2. female</td>
#       <td id="T_bd24e_row1_col3" class="data row1 col3" >676 (50.5%)<br>662 (49.5%)</td>
#       <td id="T_bd24e_row1_col4" class="data row1 col4" ><img src = "tmp/raw_data_001.png"></img></td>
#       <td id="T_bd24e_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bd24e_row2_col1" class="data row2 col1" ><strong>bmi</strong><br>[float64]</td>
#       <td id="T_bd24e_row2_col2" class="data row2 col2" >Mean (sd) : 30.7 (6.1)<br>min < med < max:<br>16.0 < 30.4 < 53.1<br>IQR (CV) : 8.4 (5.0)</td>
#       <td id="T_bd24e_row2_col3" class="data row2 col3" >548 distinct values</td>
#       <td id="T_bd24e_row2_col4" class="data row2 col4" ><img src = "tmp/raw_data_002.png"></img></td>
#       <td id="T_bd24e_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_bd24e_row3_col1" class="data row3 col1" ><strong>children</strong><br>[int64]</td>
#       <td id="T_bd24e_row3_col2" class="data row3 col2" >1. 0<br>2. 1<br>3. 2<br>4. 3<br>5. 4<br>6. 5</td>
#       <td id="T_bd24e_row3_col3" class="data row3 col3" >574 (42.9%)<br>324 (24.2%)<br>240 (17.9%)<br>157 (11.7%)<br>25 (1.9%)<br>18 (1.3%)</td>
#       <td id="T_bd24e_row3_col4" class="data row3 col4" ><img src = "tmp/raw_data_003.png"></img></td>
#       <td id="T_bd24e_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_bd24e_row4_col1" class="data row4 col1" ><strong>smoker</strong><br>[object]</td>
#       <td id="T_bd24e_row4_col2" class="data row4 col2" >1. no<br>2. yes</td>
#       <td id="T_bd24e_row4_col3" class="data row4 col3" >1,064 (79.5%)<br>274 (20.5%)</td>
#       <td id="T_bd24e_row4_col4" class="data row4 col4" ><img src = "tmp/raw_data_004.png"></img></td>
#       <td id="T_bd24e_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_bd24e_row5_col1" class="data row5 col1" ><strong>region</strong><br>[object]</td>
#       <td id="T_bd24e_row5_col2" class="data row5 col2" >1. southeast<br>2. southwest<br>3. northwest<br>4. northeast</td>
#       <td id="T_bd24e_row5_col3" class="data row5 col3" >364 (27.2%)<br>325 (24.3%)<br>325 (24.3%)<br>324 (24.2%)</td>
#       <td id="T_bd24e_row5_col4" class="data row5 col4" ><img src = "tmp/raw_data_005.png"></img></td>
#       <td id="T_bd24e_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_bd24e_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_bd24e_row6_col1" class="data row6 col1" ><strong>charges</strong><br>[float64]</td>
#       <td id="T_bd24e_row6_col2" class="data row6 col2" >Mean (sd) : 13270.4 (12110.0)<br>min < med < max:<br>1121.9 < 9382.0 < 63770.4<br>IQR (CV) : 11899.6 (1.1)</td>
#       <td id="T_bd24e_row6_col3" class="data row6 col3" >1,337 distinct values</td>
#       <td id="T_bd24e_row6_col4" class="data row6 col4" ><img src = "tmp/raw_data_006.png"></img></td>
#       <td id="T_bd24e_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
#
#     </div>
#     <style>
#     .st-collapsible {
#       background-color: #eee;
#       color: #444;
#       cursor: pointer;
#       padding: 10px;
#       width: 100%;
#       border: none;
#       text-align: left;
#       outline: none;
#       font-size: 14px;
#       border-radius: 0.5rem;
#     }
#
#     .active .st-collapsible:hover {
#       background-color: #ccc;
#     }
#
#     .st-content {
#       padding: 0 10px;
#       background-color: white;
#       max-height: 0;
#       overflow: hidden;
#       transition: max-height 0.2s ease-out;
#     }
#
#     .st-collapsible:after {
#       content: '+'; /* Unicode character for "plus" sign (+) */
#       color: #444;
#       font-weight: bold;
#       float: right;
#       margin-left: 5px;
#     }
#
#     .active:after {
#       content: '-';
#     }
#     </style><script>
#     function coll_toggle_1976(){
#         var coll = document.getElementById("btn-1976");
#         var content = document.getElementById("cont-1976");
#         coll.classList.toggle("active");
#         if (content.style.maxHeight){
#           content.style.maxHeight = null;
#           coll.innerHTML = "Show Summary - raw_data";
#         } else {
#           content.style.maxHeight = content.scrollHeight + "px";
#           coll.innerHTML = "Hide Summary - raw_data";
#         }
#     }
#
#     </script>

# %%
raw_data.stb.freq(["children"])
# Out:
#    children  count    percent  cumulative_count  cumulative_percent
# 0         0    574  42.899851               574           42.899851
# 1         1    324  24.215247               898           67.115097
# 2         2    240  17.937220              1138           85.052317
# 3         3    157  11.733931              1295           96.786248
# 4         4     25   1.868460              1320           98.654709
# 5         5     18   1.345291              1338          100.000000

# %%
raw_data.stb.missing()
# Out:
#           missing  total  percent
# age             0   1338      0.0
# sex             0   1338      0.0
# bmi             0   1338      0.0
# children        0   1338      0.0
# smoker          0   1338      0.0
# region          0   1338      0.0
# charges         0   1338      0.0

# %%
raw_data.groupby(["smoker", "sex"]).agg({"charges": ["mean", "min", "max"]}).stb.subtotal()
# Out:
#                                  charges
#                                     mean         min           max
# smoker      sex
# no          female           8762.297300   1607.5101   36910.60803
#             male             8087.204731   1121.8739   32108.66282
#             no - subtotal   16849.502031   2729.3840   69019.27085
# yes         female          30678.996276  13844.5060   63770.42801
#             male            33042.005975  12829.4551   62592.87309
#             yes - subtotal  63721.002252  26673.9611  126363.30110
# grand_total                 80570.504282  29403.3451  195382.57195

# %%
raw_data.sketch.ask("Which columns are integer type?")
# Out:
# index, age, children, and charges columns are integer type.

# %%
raw_data.sketch.howto("Plot the charges versus sex")
# Out:
# <div style="display:flex;flex-direction:row;justify-content:space-between;">
#                 <pre style="width: 100%; white-space: pre-wrap;" id="3c5c05e5-87e7-4265-8096-665980396946">
# import matplotlib.pyplot as plt
#
# # Get the data for plotting
# x = raw_data['sex']
# y = raw_data['charges']
#
# # Create the plot
# plt.scatter(x, y)
# plt.xlabel('Sex')
# plt.ylabel('Charges')
# plt.title('Charges vs Sex')
#
# # Show the plot
# plt.show()
# </pre>
#                 <button style="height: fit-content;" onclick="navigator.clipboard.writeText(JSON.parse(atob(``)))">Copy</button>
#                 </div>

# %%
# Find out the average age of the patients in the dataset.
def avgAge(df):
    sumAge = 0;
    for i in range(len(df)):
        sumAge += df["age"][i]
    return sumAge/len(df)

avgAge(raw_data)
# Out:
# 39.20702541106129

# %%
# Analyze where a majority of the individuals are from.
def peopleRegion(df):
    regionsCount = {}
    regionsPercent = {}
    for i in range(len(df)):
        currRegion = df["region"][i]
        if currRegion not in regionsCount:
            regionsCount[currRegion] = 1
        else:
            regionsCount[currRegion] += 1

    for region in regionsCount:
        regionsPercent[region] = "{:.2%}".format(regionsCount[region] / len(df))

    return regionsCount, regionsPercent

peopleRegion(raw_data)
# Out:
# ({'southwest': 325, 'southeast': 364, 'northwest': 325, 'northeast': 324},
#  {'southwest': '24.29%',
#   'southeast': '27.20%',
#   'northwest': '24.29%',
#   'northeast': '24.22%'})

# %%
# Look at the different costs between smokers vs. non-smokers.
def avgSmokerCost(df):
    sumCost = {}
    avgCost = {}
    countSmokers = {}
    for i in range(len(df)):
        currSmoker = df["smoker"][i]
        smokerCost = df["charges"][i]
        
        if currSmoker not in sumCost:
            sumCost[currSmoker] = smokerCost
            countSmokers[currSmoker] = 1
        else:
            sumCost[currSmoker] += smokerCost
            countSmokers[currSmoker] += 1

    for cost in sumCost:
        avgCost[cost] = sumCost[cost] / countSmokers[cost]

    return avgCost

avgSmokerCost(raw_data)
# Out:
# {'yes': 32050.23183153285, 'no': 8434.268297856199}

# %%
# Figure out what the average age is for someone who has at least one child in this dataset.
